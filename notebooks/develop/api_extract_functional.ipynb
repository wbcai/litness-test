# %%
import billboard
from datetime import datetime
import numpy as np
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import logging

# %%
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %%
def get_billboard_charts(start_year = 1990, end_year = 2020, chart_name = 'rap-song', top_x = 25):
    
    """Fetch tracks from monthly billboard chart
    
    Args: 
        start_year (int): starting year of query
        end_year (int): ending year of query
        chart_name (int): name of billboard chart
        top_x(int): save top x songs from chart
        
    Return:
        query_results (obj): 'list' of artist, song, chart date, and chart name
    
    """
    
    currentmonth = datetime.now().month
    currentyear = datetime.now().year
    
    # Ensure end year is not in the future
    if end_year > currentyear:
        end_year = currentyear
    
    # Ensure start year is not before 1990 (no rap chart)
    if start_year < 1990:
        start_year = 1990
    
    # Create list of monthly dates from start_year to year before end_year
    years = [x for x in range(start_year, end_year)]
    months = ['-01-01','-02-01','-03-01','-04-01','-05-01',  '-06-01', '-07-01','-08-01','-09-01','-10-01','-11-01','-12-01']
    query_dates = [str(y) + d for y in years for d in months]
    
    # Append monthly dates of end_year, accounting for current date
    if end_year < currentyear:
        cur_year_dates = [str(end_year) + d for d in months]
        query_dates.extend(cur_year_dates)
    else:
        cur_year_dates = [str(end_year) + d for d in months[:currentmonth]]
        query_dates.extend(cur_year_dates)
        
    # Fetch chart data from Billboard API

    retry = [] # Unsuccessful queries from first try
    query_results = [] # Results from query
    unsuccessful = [] # Final queries not successful after second try 
    
    
    for qdate in query_dates:
        
        try:
            chart = billboard.ChartData(chart_name, date = qdate)
            results = [[chart[i].artist, chart[i].title, qdate, chart_name] for i in range(0, top_x)]
            query_results.extend(results)
            
            logger.info("{} ... successful query".format(qdate))

        except:
            retry.append(qdate) # if unsuccessfull, add to retry list
            print('{} not found'.format(qdate))
    
    for qdate in retry:
        
        try:
            chart = billboard.ChartData(chart_name, date = qdate)
            results = [[chart[i].artist, chart[i].title, qdate, chart_name] for i in range(0, top_x)]
            query_results.extend(results)
            
            logger.info("{} ... successful query".format(qdate))

        except:
            unsuccessful.append(qdate) # if unsuccessfull, add to retry list
            print('{} not found'.format(qdate))
            
    logger.warning("{} unsuccessful queries".format(len(unsuccessful)))
    
    return query_results

# %%
def prep_spotify_query(query_results):
    
    """ Manipulate and concatenate artist and song information based on Spotify API query format. Remove duplicate songs.
    
    Args:
        query_results (obj): 'List' of queries from get_billboard_charts
    
    Return:
        reesults_df (obj): 'DataFrame' of songs with Spotify query column
    
    """
    
    # Remove duplicates
    results_df = pd.DataFrame(query_results, columns = ['artist', 'track', 'date', 'chart'])
    results_df = (results_df.sort_values(by = 'date', ascending = False)
                            .groupby(['artist', 'track']).head(1)
                            .reset_index(drop = True))
    
    
    # Remove parts of the song/artist name that can prevent a successful Spotify query
    
    results_df['artist_q'] = results_df.artist.str.split(' Feat', 1).str[0]
    results_df['artist_q'] = results_df.artist_q.str.split('\(Feat', 1).str[0]
    results_df['artist_q'] = results_df.artist_q.str.split(' &', 1).str[0]
    results_df['artist_q'] = results_df.artist_q.str.split(' ,', 1).str[0]
    results_df['artist_q'] = results_df.artist_q.str.split(" Tell'em", 1).str[0]
    results_df['artist_q'] = results_df.artist_q.str.split(" Tell 'em", 1).str[0]
    results_df['artist_q'] = results_df.artist_q.str.replace(' X ', ' ')
    results_df['artist_q'] = results_df.artist_q.str.replace(" Co-Starring ", " ")
    results_df['artist_q'] = results_df.artist_q.str.replace("F/", "")
    results_df['artist_q'] = results_df.artist_q.str.replace(' Duet With ', ' ')
    results_df['track_q'] = results_df.track.str.split(" \(", 1).str[0]
    results_df['track_q'] = results_df.track_q.str.split(" Feat", 1).str[0]
    results_df['track_q'] = results_df.track_q.str.split("\(Feat", 1).str[0]
    results_df['track_q'] = results_df.track_q.str.split("/", 1).str[0]
    
    # Create final query column
    results_df['spotify_query'] = (results_df.artist_q + ' ' + results_df.track_q).str.replace(' ', '+')
    
    results_df.drop(['artist_q', 'track_q'], axis = 1, inplace = True)
    
    return results_df

# %%
def concat_charts(rap_df, all_df):
    
    """ Create dataframe of songs from hot-100 and rap-song charts. Remove hot-100 songs that are also in rap-song 
    
    """
    
    rap_songs = rap_df.track.values.tolist() # list of songs from rap chart
    
    all_df_no_rap = all_df.loc[~all_df.track.isin(rap_songs), :] # remove rap chart songs from hot-100 chart
    
    concat_df = pd.concat([rap_df, all_df_no_rap]) # combine dataframes
    
    logger.info("{} songs removed from Hot 100".format(len(all_df) - len(all_df_no_rap)))
    
    return concat_df

# %%
def get_spotify_metadata(query_df, cid, secret):
    
    """Obtain song metadata from Spotify API using Spotipy library
    
    Args:
    
        query_df (obj): 'DataFrame' with spotify_query column
        cid (str): CID Spotify credentials
        secret (str): Secret key for Spotify credentials
        
    Return:
    
        results (obj): 'DataFrame' of Spotify metadata
    
    """
    
    
    # Configure spotipy with Spotify credentials
    client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
    sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

    
    search_list = query_df['spotify_query'].values.tolist()
    
    query_found = []
    audio_features = []
    not_found = []
    
    # Fetch track metadata from Spotify
    for search in search_list:

        try:
            query = sp.search(search)
            song_id = query['tracks']['items'][0]['id']

            query_found.append(search)
            audio_feature = sp.audio_features(song_id)[0]
            audio_features.append(audio_feature)

        except:
            not_found.append(search)
            print(search, ' not found')
            
    logger.warning("{} songs not found".format(len(not_found)))
            
    spotify_features = pd.DataFrame(audio_features)
    spotify_features['spotify_query'] = query_found
    
    results = query_df.merge(spotify_features, on = 'spotify_query')
    
    return results

# %%
hot_100 = get_billboard_charts(chart_name = 'hot-100', top_x = 50)
# Out:
# 1992-12-01 not found
# 1994-11-01 not found
# 1996-01-01 not found
# 1997-04-01 not found
# 1997-08-01 not found
# 1997-09-01 not found
# 1999-12-01 not found
# 2000-02-01 not found
# 2000-07-01 not found
# 2000-10-01 not found
# 2000-12-01 not found
# 2001-01-01 not found
# 2001-02-01 not found
# 2001-08-01 not found
# 2001-10-01 not found
# 2002-05-01 not found
# 2002-07-01 not found
# 2002-10-01 not found
# 2003-05-01 not found
# 2003-11-01 not found
# 2003-12-01 not found
# 2004-06-01 not found
# 2004-07-01 not found
# 2004-11-01 not found
# 2005-09-01 not found
# 2005-12-01 not found
# 2006-03-01 not found
# 2006-06-01 not found
# 2006-07-01 not found
# 2007-03-01 not found
# 2007-04-01 not found
# 2007-05-01 not found
# 2008-10-01 not found
# 2009-04-01 not found
# 2011-04-01 not found
# 2014-04-01 not found
# 2016-07-01 not found
# 1992-12-01 not found
# 2001-01-01 not found
# 2001-02-01 not found
# 2001-08-01 not found
# 2002-05-01 not found
# 2003-11-01 not found

# %%
hot100_df = prep_spotify_query(hot_100)

# %%
toprap = get_billboard_charts(chart_name = 'rap-song', top_x = 25)

# %%
toprap_df = prep_spotify_query(toprap)

# %%
all_df = concat_charts(toprap_df, hot100_df)

# %%
all_df.to_csv("all_df_0510.csv")

# %%
cid = "4d873f4f1fe442d399438bdef5efc4a6"
secret = "5edc8c8b39764a0fbf920ca326a3cbbc"

# %%
spotify_df = get_spotify_metadata(all_df, cid, secret)
# Out:
# Lil+Tecca+Ran$om  not found
# retrying after...3secs
# Yella+Beezy,+Gucci+Mane+Bacc+At+It+Again  not found
# retrying after...1secs
# Quavo+W+O+R+K+I+N++M+E  not found
# J.+Cole+Kevin's+Heart  not found
# Derez+De'Shon+Hardaway  not found
# ScHoolboy+Q,+2+Chainz+X  not found
# Chris+Brown+Pills+And+Automobiles  not found
# retrying after...2secs
# 2+Chainz+x+Gucci+Mane+x+Quavo+Good+Drank  not found
# Kendrick+Lamar+Untitled+02+l+06.23.2014.  not found
# Kendrick+Lamar+Untitled+07+l+Levitate  not found
# iLoveMemphis+Lean+&+Dabb  not found
# retrying after...3secs
# retrying after...1secs
# retrying after...1secs
# Steve+Aoki,+Chris+Lake+Delirious  not found
# Wiz+Khalifa+Feautring+Project+Pat+KK  not found
# QUE.+OG+Bobby+Johnson  not found
# retrying after...1secs
# A$AP+Rocky+Kendrick+Lamar,+Joey+Bada$$,+YelaWolf,+Danny+Brown,+Action+Bronson+1Train  not found
# retrying after...2secs
# E-40+With+YG,+iAMSU!+Function  not found
# retrying after...2secs
# J.+Cole+Who+Dat  not found
# T.I.+I'm+Back  not found
# Fat+Joe+(HaHa)+Slow+Down  not found
# Nicki+Minaj+I+Get+Crazy  not found
# Drake+I'm+Going+In  not found
# Eminem+The+Warning  not found
# Ludacris+T-Pain+One+More+Drink  not found
# Ludacris+Co-Staring+Plies+Nasty+Girl  not found
# Jay-Z+Brooklyn+Go+Hard  not found
# Lil+Wil+Bust+It+Wide+Open  not found
# Ludacris+Chris+Brown+What+Them+Girls+Like  not found
# JAY-Z+Jockin'+JAY-Z  not found
# Slim+So+Fly  not found
# retrying after...1secs
# Styles+P+Blow+Ya+Mind  not found
# retrying after...1secs
# R.+Kelly+Or+Bow+Wow++I'm+A+Flirt  not found
# The+Fixxers+AKA+DJ+Quik+Can+U+Werk+Wit+Dat  not found
# retrying after...1secs
# Cham+Ghetto+Story+Chapter+2  not found
# Cadillac+Don+Peanut+Butter+&+Jelly  not found
# DJ+Khaled+Holla+At+Me  not found
# retrying after...1secs
# Ying+Yang+Twins+Git+It  not found
# retrying after...1secs
# retrying after...1secs
# R.+Kelly+Big+Chips  not found
# Dem+Franchize+Boyz+White+Tee's  not found
# Shawnna+Shake+That+Sh**  not found
# T.O.K.+Gal+Yuh+Ah+Lead  not found
# Obie+Trice+The+Set+Up  not found
# Eminem,+50+Cent+Hail+Mary  not found
# Missy+"Misdemeanor"+Elliott+P***ycat  not found
# The+Notorious+B.I.G.+Realest+N*ggas  not found
# Irv+Gotti+Presents+The+Inc.+Down+4+U  not found
# Rozelly+Presents+Da+Fam+Bang+My+Hit  not found
# Strik+9ine+Dansin+Wit+Wolvez  not found
# Dem+Ghetto+Playa$+Ghetto+Millionaire  not found
# No+Good+Ballin'+Boy  not found
# Levert+Agee+Stop+Playin'  not found
# Won-G+Put+It+Inside  not found
# Green+Eyez+Mama's+Baby,+Poppa's+Maybe  not found
# Big+Logic+Hyde+Ha  not found
# Willie+D+Dear+God  not found
# Mr.+Cheeks+Friday+Night  not found
# Beelow+Do+Ya+Thang+Girl  not found
# Lil'+Ru+Will+Destroy  not found
# Redd+Eyezz+Put+Yo+Sets+Up  not found
# EL-P+Deep+Space+9mm  not found
# R.+Kelly+Take+You+Home+With+Me+a.k.a+Body  not found
# Crimewave+Think+Big  not found
# Bear+Witnez!+Can+I+Get+That?!!?  not found
# Dennis+Da+Menace+Buster  not found
# Roy+Jones,+Jr.+That+Was+Then  not found
# Pretty+Willie+Roll+Wit+Me  not found
# Boobakaw+And+Tha+Wild+Younginz+Rock+Em  not found
# Original+P+Introducing+Hyped+Up+Westbound+Soljaz+Jump+Up+In+The+Air  not found
# The+Rawlo+Boys+Ain't+Nobody  not found
# Benzino+Boottee  not found
# Twin+And+Alchemist+Different+Worlds  not found
# Ludacris,+LL+Cool+J+Fatty+Girl  not found
# Skip+Pimps  not found
# Minott+Playa+Playa  not found
# Cash+Ground+Zero  not found
# Rayvon+2-Way  not found
# Po'+White+Trash+And+The+Trailer+Park+Symphony+Po'+Punch  not found
# R.L.,+Snoop+Dogg+Do+U+Wanna+Roll  not found
# Sherm+Get+Mo  not found
# John+Got'ti+Cut+Throat  not found
# Chocolate+Bandit+Gotta+Have+It  not found
# retrying after...2secs
# Dena+Cali+I'm+Your+Girl  not found
# Won-G+Nothing's+Wrong  not found
# Phatty+Banks+Presents+Club+Drama+The+Bedrock  not found
# TaTa+++Brando+Let's+Be+Friends  not found
# Survivalist+Bounce  not found
# Big+Lew+BKA+Popeye+Reds+How+We+Do  not found
# Rising+Son+Make+It+Vibrate  not found
# Baby+S+I'm+Ghetto  not found
# The+Young+Millionaires+Grippin+Grain  not found
# Young+Phantom+All+My+Thugs  not found
# Jailbird+Trunk+Fall+Off  not found
# Empty+Mynd+Funk  not found
# Drunken+Master+50+Playaz+Deep  not found
# QB+Finest+Oochie+Wally  not found
# Skillz+Y'all+Don't+Wanna  not found
# Kool+Keith+Thug+Or+What?  not found
# David+Bowie+With+Queen+Latifah+Fame+90  not found
# Silk+Tymes+Leather+The+Woman+In+Me  not found
# Audio+Two+On+The+Road+Again  not found
# Young+And+Restless+"B"+Girls  not found
# Kid+'N+Play+Funhouse  not found
# Professor+Griff+Pawns+In+The+Game  not found
# Oaktown's+3.5.7+Juicy+Gotcha+Crazy  not found
# M.C.+Shy-D+Don't+Sweat+Me  not found
# Kid+Sensation+Back+To+Boom  not found
# XClan+Raise+The+Flag  not found
# Mark+Dee+Get+A+Hold+Of+Yourself  not found
# Rodney+O+Say+It+Loud  not found
# Missy+Mist+Gettin'+Bass  not found
# Kenny+B+Devine+Bass+In+The+Box  not found
# Bobby+Jimmy+Somebody+Farted  not found
# Maestro+Fresh-Wes+Let+Your+Back+Bone+Slide  not found
# Divine+Styler+Ain't+Sayin'+Nothin'  not found
# The+2+Live+Crew+C'mon+Babe  not found
# The+Young+And+The+Restless+Poison+Ivy  not found
# T-Ski+Pump+That+Beat  not found
# Redhead+Kingpin+Pump+It+Hottie  not found
# Wreckx-N-Effect+Juicy  not found
# Rob+Base+Turn+It+Out  not found
# Mr.+Lee+Get+Busy  not found
# Def+Dames+976-Boom  not found
# Kwame+Sweet+Thing  not found
# Gang+Starr+Positivity  not found
# Serious-Lee-Fine+Nothing+Can+Stop+Us  not found
# Donald-D+F.B.I.  not found
# Arabian+Prince+She's+Got+A+Big+Posse  not found
# Awesome+Dre+Frankly+Speaking  not found
# 3rd+Bass+Steppin'+Into+The+A.M.  not found
# Gucci+Crew+II+Five+Dollar+High  not found
# Black+Rock+'N'+Ron+True+Feelings  not found
# Chubb+Rock+Stop+That+Train  not found
# Carly+Pearce+I+Hope+You're+Happy+Now  not found
# retrying after...1secs
# Perry+Como+And+The+Fontane+Sisters+With+Mitchell+Ayres+And+His+Orchestra+It's+Beginning+To+Look+A+Lot+Like+Christmas  not found
# XXXTENTACION+F**k+Love  not found
# retrying after...1secs
# Kygo+x+Selena+Gomez+It+Ain't+Me  not found
# retrying after...1secs
# retrying after...2secs
# retrying after...2secs
# retrying after...1secs
# Craig+Wayne+Boyd+My+Baby's+Got+A+Smile+On+Her+Face  not found
# retrying after...2secs
# Florida+Georgia+Line+Ft.+Jason+Derulo+This+Is+How+We+Roll  not found
# retrying after...2secs
# retrying after...1secs
# Alison+Gold+Chinese+Food  not found
# Tim+McGraw+With+Taylor+Swift+Highway+Don't+Care  not found
# retrying after...1secs
# retrying after...3secs
# retrying after...2secs
# retrying after...1secs
# retrying after...1secs
# retrying after...1secs
# Kenny+Chesney+With+Dave+Matthews+I'm+Alive  not found
# Kenny+Chesney+With+Mac+McAnally+Down+The+Road  not found
# Kenny+Chesney+With+The+Wailers+Everybody+Wants+To+Go+To+Heaven  not found
# The+Rock+Heroes+All+Summer+Long  not found
# Hit+Masters+All+Summer+Long  not found
# Usher+Love+In+This+Club+Part+II  not found
# David+Cook+I+Still+Haven't+Found+What+I'm+Looking+For  not found
# David+Cook+Dream+Big  not found
# David+Cook+The+World+I+Know  not found
# David+Cook+Billie+Jean  not found
# David+Cook+I+Don't+Want+To+Miss+A+Thing  not found
# David+Archuleta+Imagine  not found
# retrying after...1secs
# Keyshia+Cole+Introducing+Amina+Shoulda+Let+You+Go  not found
# retrying after...1secs
# Zac+Efron+You+Are+The+Music+In+Me  not found
# Freak+Nasty+Do+It+Just+Like+A+Rockstar  not found
# retrying after...1secs
# retrying after...1secs
# American+Idol+Finalists+Season+4+When+You+Tell+Me+That+You+Love+Me  not found
# The+Used+And+My+Chemical+Romance+Under+Pressure  not found
# Various+Artists+Across+The+Universe  not found
# retrying after...1secs
# retrying after...2secs
# retrying after...2secs
# retrying after...1secs
# retrying after...2secs
# Lil'+Mo+Superwoman+Pt.+II  not found
# retrying after...1secs
# Olivia+Bizounce  not found
# retrying after...1secs
# retrying after...1secs
# Kenny+Rogers+With+Alison+Krauss+Buy+Me+A+Rose  not found
# retrying after...1secs
# retrying after...2secs
# Marc+Nelson+15+Minutes  not found
# Silkk+The+Shocker+It+Ain't+My+Fault+1+&+2  not found
# retrying after...1secs
# Myron+Destiny  not found
# Link+Whatcha+Gone+Do?  not found
# INOJ/LATHUN+Love+You+Down  not found
# Missy+"Misdemeanor"+Elliott+Sock+It+2+Me  not found
# retrying after...2secs
# Various+Artists+ESPN+Presents+The+Jock+Jam  not found
# Raybon+Bros.+Butterfly+Kisses  not found
# 3rd+Party+Can+U+Feel+It  not found
# retrying after...2secs
# Bill+Engvall+With+Special+Guest+Travis+Tritt+Here's+Your+Sign  not found
# retrying after...2secs
# Adam+Clayton+Theme+From+Mission:+Impossible  not found
# Solo+Where+Do+U+Want+Me+To+Put+It  not found
# retrying after...2secs
# Tyler+Collins+Never+Alone  not found
# IV+Xample+I'd+Rather+Be+Alone  not found
# Subway++This+Lil'+Game+We+Play  not found
# 4PM+Sukiyaki  not found
# N2U+I+Miss+You  not found
# retrying after...2secs
# retrying after...2secs
# Fu-Schnickens+W/+Shaquille+O'Neal+What's+Up+Doc?  not found
# U.N.V.+Something's+Goin'+On  not found
# Clint+Black+With+Wynonna+A+Bad+Goodbye  not found
# Jeremy+Jordan+Wannagirl  not found
# Prince+And+The+New+Power+Generation+7  not found
# retrying after...2secs
# Prince+And+The+New+Power+Generation+The+Morning+Papers  not found
# Lo-Key?+I+Got+A+Thang+4+Ya!  not found
# The+S.O.U.L.+S.Y.S.T.E.M.+It's+Gonna+Be+A+Lovely+Day  not found
# retrying after...1secs
# Prince+And+The+New+Power+Generation+My+Name+Is+Prince  not found
# Luther+Vandross+And+Janet+Jackson+With+BBD+And+Ralph+Tresvant+The+Best+Things+In+Life+Are+Free  not found
# Linear+T.L.C.  not found
# Prince+And+The+N.P.G.+Money+Don't+Matter+2+Night  not found
# Colourhaus+Innocent+Child  not found
# Cause+And+Effect+You+Think+You+Know+Her  not found
# Chris+Walker+Take+Time  not found
# NKOTB+If+You+Go+Away  not found
# retrying after...3secs
# Gerald+Levert+(Duet+With+Eddie+Levert)+Baby+Hold+On+To+Me  not found
# Prince+And+The+N.P.G.+Diamonds+And+Pearls  not found
# Clivilles+A+Deeper+Love  not found
# Stacy+Earl+Love+Me+All+Up  not found
# The+Party+In+My+Dreams  not found
# Natural+Selection+Hearts+Don't+Think  not found
# Prince+And+The+N.P.G.+Cream  not found
# Angelica+Angel+Baby  not found
# C+C+Music+Factory+Presents+Zelma+Davis+Just+A+Touch+Of+Love  not found
# Rhythm+Syndicate+Hey+Donna  not found
# Prince+And+The+N.P.G.+Gett+Off  not found
# Russ+Irwin+My+Heart+Belongs+To+You  not found
# Or-N-More++Everyotherday  not found
# PC+Quest+After+The+Summer's+Gone  not found
# retrying after...1secs
# David+A.+Stewart+Introducing+Candy+Dulfer+Lily+Was+Here  not found
# Desmond+Child+Love+On+A+Rooftop  not found
# Lisa+Lisa+And+Cult+Jam+Let+The+Beat+Hit+'Em  not found
# Londonbeat+A+Better+Love  not found
# Titiyo+My+Body+Says+Yes  not found
# The+Rude+Boys+Written+All+Over+Your+Face  not found
# The+Rebel+Pebbles+Dream+Lover  not found
# retrying after...1secs
# Enigma+Sadeness+Part+1  not found
# The+Fixx+How+Much+Is+Enough  not found
# The+Escape+Club+Call+It+Poison  not found
# Michel'le+Something+In+My+Heart  not found
# Harriet+Temple+Of+Love  not found
# retrying after...1secs
# 2nu+This+Is+Ponderous  not found
# Elisa+Fiorillo+On+The+Way+Up  not found
# Breathe+Does+She+Love+That+Man?  not found
# Robert+Palmer+You're+Amazing  not found
# Donny+Osmond+My+Love+Is+A+Fire  not found
# David+Cassidy+Lyin'+To+Myself  not found
# Al+B.+Sure!+Missunderstanding  not found
# Breathe+Say+A+Prayer  not found
# Glenn+Medeiros+All+I'm+Missing+Is+You  not found
# Sydney+Youngblood+I'd+Rather+Go+Blind  not found
# Stevie+B+Love+And+Emotion  not found
# The+West+Coast+Rap+All-Stars+We're+All+In+the+Same+Gang  not found
# Brother+Beyond+The+Girl+I+Used+To+Know  not found
# Indecent+Obsession+Tell+Me+Something  not found
# retrying after...2secs
# Louie+Louie+Sittin'+In+The+Lap+Of+Luxury  not found
# Giant+I'll+See+You+In+My+Dreams  not found
# Rod+Stewart+With+Ronald+Isley+This+Old+Heart+Of+Mine  not found
# Perfect+Gentlemen+Ooh+La+La  not found
# Whistle+Always+And+Forever  not found
# Michel'le+Nicety  not found
# A'me+Lorain+Whole+Wide+World  not found
# The+Cover+Girls+All+That+Glitters+Isn't+Gold  not found
# Corey+Hart+A+Little+Love  not found
# The+U-Krew+If+U+Were+Mine  not found
# D-Mob+Introducing+Cathy+Dennis+C'mon+And+Get+My+Love  not found
# Paula+Abdul+(Duet+With+The+Wild+Pair)+Opposites+Attract  not found
# The+Brat+Pack+You're+The+Only+Woman  not found
# Jaya+If+You+Leave+Me+Now  not found
# Expose+Tell+Me+Why  not found
# Kevin+Paige+Anything+I+Want  not found

# %%
spotify_df.to_csv("spotify_df_0510.csv")
